# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
df = pd.read_csv(r"C:\Users\nikhi\Desktop\Data_analyst_coursework\Machine Learning\salary_data.csv")

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
x = df.iloc[:,0].values
y = df.iloc[:,1].values

# %%
type(x)
# Out:
# numpy.ndarray

# %%
type(y)
# Out:
# numpy.ndarray

# %%
plt.scatter(x,y,c="brown")
plt.xlabel('Years of experience')
plt.ylabel('salary')
plt.title('Y.O.E vs Salary')
plt.show()

# %%
x_bar = np.mean(x)
y_bar = np.mean(y)
x_bar,y_bar
# Out:
# (np.float64(5.3133333333333335), np.float64(76003.0))

# %%
numerator = np.sum((x-x_bar)*(y-y_bar))
denominator = np.sum((x-x_bar)**2)

# %%
teta1 = numerator/denominator

# %%
teta0 = y_bar-(teta1 * x_bar)

# %%
teta0
# Out:
# np.float64(25792.20019866869)

# %%
y_pred = teta1*x + teta0

# %%
plt.scatter(x,y,c="#28ff03")
plt.scatter(x, y_pred, c="#ff0303")
plt.plot(x,y_pred,c="black")
for i in range(len(x)):
    plt.plot([x[i], x[i]],[y[i],y_pred[i]],color="brown")
plt.xlabel('Years of experience')
plt.ylabel('salary')
plt.title('Y.O.E vs Salary')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mse = mean_squared_error(y,y_pred)
print(f"The mean squared error is {mse}")
# Out:
# The mean squared error is 31270951.72228097

# %%
r2 = r2_score(y,y_pred)
print(f"The r2 score is {r2}")
# Out:
# The r2 score is 0.9569566641435086
