# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\SURENDRA\Downloads\salary_data.csv")

# %%
df
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
x = df['YearsExperience'].values
y = df['Salary'].values
x,y
# Out:
# (array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#          4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#          7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5]),
#  array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#          64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#          66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#         109431, 105582, 116969, 112635, 122391, 121872]))

# %%
a=0
b=0
n=len(x)
alpha=0.01
cost=[]
n,alpha
# Out:
# (30, 0.01)

# %%
for i in range(1000):
    y_pred = b * x + a
    c1 = (1/n) * np.sum((y - y_pred)**2)
    cost.append(c1)
    d_a = (-2/n) * sum(y - y_pred)
    d_b = (-2/n) * sum(x*(y - y_pred))
    a = a - alpha * d_a
    b = b - alpha * d_b

# %%
a,b
# Out:
# (np.float64(25448.181745946968), np.float64(9501.013219578916))

# %%
plt.scatter(x, y, color='#00F7FF')
plt.plot(x, y_pred, color='#FF0087')
plt.title("Linear Regression using Gradient Descent")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(x, y, color="#00F7FF")
plt.scatter(x,y_pred,color="#8100D1")
plt.plot(x, y_pred,color="#FF0087")
plt.vlines(x, y, y_pred)
plt.title("Linear Regression using Gradient Descent")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.plot(range(1000),cost,color="#FF0087")
plt.title("Cost_Function vs Iterations")
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.show()
